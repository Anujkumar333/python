# %%
import pandas as pd

# %%
iris=pd.read_csv("iris.csv")
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
import numpy as np
from matplotlib import pyplot  as plt

# %%
iris=pd.read_csv("iris.csv")
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
x=[1,2,30,4,5,70,8]
y=[20,4,6,60,10,14,16]
print(x)
print(y)
# Out:
# [1, 2, 30, 4, 5, 70, 8]
# [20, 4, 6, 60, 10, 14, 16]

# %%
z=tuple(x)
z
# Out:
# (1, 2, 30, 4, 5, 70, 8)

# %%
# plt.plot(petal.width,sepal.width,dataset = iris)
plt.plot(x,y)
plt.title("line_graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.plot(x,y,linestyle=":",color="g",linewidth=5)
plt.plot(x,z,linestyle=":",color ="r",linewidth=6)
plt.plot(y,z,linestyle=":",color="y",linewidth=7)
plt.title("line_graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(ture)
#plt.zlabel("z-axis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       5 plt.xlabel("x-axis")
#       6 plt.ylabel("y-axis")
# ----> 7 plt.grid(ture)
#       8 #plt.zlabel("z-axis")
#       9 plt.show()
#
# NameError: name 'ture' is not defined

# %%
print(x)
print(y)
print(z)

# %% [markdown]
# ### create a sub plot in line chart

# %%
plt.subplot(1,3,1)
plt.plot(x,y,linestyle=":",c="g",linewidth=4)
plt.subplot(1,3,2)
plt.plot(y,z,c="y",linewidth=5)
plt.subplot(1,3,3)
plt.plot(x,z,linestyle=":",c="r",linewidth=6)
plt.show()

# %% [markdown]
# ### create a bar plot for data visualization

# %%
st={"anuj":89,"anup":98,"sk":78,"pk":78}
st
# Out:
# {'anuj': 89, 'anup': 98, 'sk': 78, 'pk': 78}

# %%
names=list(st.keys())
marks=list(st.values())

# %%
print(marks)
print(names)
# Out:
# [89, 98, 78, 78]
# ['anuj', 'anup', 'sk', 'pk']

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
plt.bar(iris["sepal.length"],iris["variety"],color="g")
plt.title("veticlly bar chart")
plt.xlabel("name of student")
plt.ylabel("marks of student")
plt.show()

# %% [markdown]
# ### creating a horizontal bar chart

# %%
plt.barh(names,marks,color="orange")
plt.title("veticlly bar chart")
plt.ylabel("name of student")
plt.xlabel("marks of student")
plt.show()

# %% [markdown]
# ### creating a subplot of bar chart with line chart

# %%
plt.subplot(2,4,1)
plt.bar(names,marks,color="g")
plt.title("veticlly bar chart")
plt.xlabel("name of student")
plt.ylabel("marks of student")


plt.subplot(2,4,2)
plt.barh(names,marks,color="orange")
plt.title("veticlly bar chart")
plt.ylabel("name of student")
plt.xlabel("marks of student")

plt.subplot(2,4,3)
plt.plot(x,y,linestyle=":",c="g",linewidth=4)


plt.subplot(2,4,4)
plt.plot(x,z,linestyle=":",c="r",linewidth=6)
plt.show()

# %% [markdown]
# ### creating a scatter plot with using scattter key word

# %%
print(x)
y
# Out:
# [1, 2, 30, 4, 5, 70, 8]
# [20, 4, 6, 60, 10, 14, 16]

# %%
plt.scatter(x,y)
plt.show()

# %%
z
# Out:
# (1, 2, 30, 4, 5, 70, 8)

# %% [markdown]
# ### two scatter plot in one dashboard

# %%
plt.scatter(x,y,marker="*",color="black",s=500)
plt.scatter(y,z)
plt.scatter(x,z)

# %% [markdown]
# ### adding a title of graph

# %%
plt.scatter(x,y,marker="*",color="black",s=500)
plt.scatter(y,z,marker="*",color="b",s=50)
plt.scatter(x,z,marker="*",color="orange",s=36)

# %% [markdown]
# ### creating a sub plot in one dashboard

# %%
plt.subplot(1,3,1)
plt.scatter(x,y,marker="*",color="black",s=50)
plt.subplot(1,3,2)
plt.scatter(y,z,marker="*",color="b",s=50)
plt.subplot(1,3,3)
plt.scatter(x,z,marker="*",color="orange",s=36)

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
plt.hist(iris["sepal.length"],bins=30,color="r")
plt.show()

# %%
data=list(iris["sepal.length",'sepal.width','peta.length'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('sepal.length', 'sepal.width', 'peta.length')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
iris["sepal.length"]

# %% [markdown]
# #### creating a box plot

# %%
one=[1,5,6,3,3,8,5,4]
two=[2,5,6,8,9,3,4,6]
three=[12,19,16,14,15,17,18,16]

# %%
data=list([one,two,three])
data

# %%
plt.boxplot(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plt.boxplot(data)
#       2 plt.show()
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## create a viuolinplot

# %%
plt.violinplot(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plt.violinplot(data)
#       2 plt.show()
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### create a pie chart

# %%
print(names)
print(marks)
# Out:
# ['anuj', 'anup', 'sk', 'pk']
# [89, 98, 78, 78]

# %%
plt.pie(marks,labels=names)
plt.show()

# %% [markdown]
# ### autopact use for oersentage sine
# ### adding a persentage

# %%
plt.pie(marks,labels=names,autopct='%0.1f%%')
plt.title("pie chart")
plt.show()

# %% [markdown]
# ## creating a doughggnut chart

# %%
plt.pie(marks,labels=names,autopct='%0.1f%%',radius=2)
plt.pie([1],color=['w'],radius=1)
plt.title("pie chart")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 plt.pie(marks,labels=names,autopct='%0.1f%%',radius=2)
# ----> 2 plt.pie([1],color=['w'],radius=1)
#       3 plt.title("pie chart")
#       4 plt.show()
#
# TypeError: pie() got an unexpected keyword argument 'color'

# %% [markdown]
# # working with seaborn libtrery

# %% [markdown]
# # import seaborn with matplotlib

# %%
import seaborn as sns
sns.set(style="whitegrid")

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## load a data set for work with seaborn

# %%
iris=sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# #### create a line plot with sns librery

# %%
sns.lineplot(y="sepal_length",x="petal_length",data=iris,color="orange")
plt.show()

# %% [markdown]
# ### create a line chart

# %%
sns.lineplot(x="sepal_length",y="petal_length",data=iris,hue="species",style="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ### addding a line style buy using sns lib lineplot

# %%
sns.lineplot(x="sepal_length",y="petal_length",data=iris,hue="species",style="species")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### adding a marker point with line grid

# %%
sns.lineplot(x="sepal_length",y="petal_length",data=iris,hue="species",style="species",marker=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# #### creating a barplot with sns librery

# %%
sns.barplot(y="sepal_length",x="species",data=iris)
plt.show()

# %%
udsi=pd.read_csv("udsi.csv")
udsi.head()
# Out:
#   Class Section         Name  Gender  Student_PEN  Student_State_Code  \
# 0    VI       A  AFREEN BANO  Female  22713987605                 NaN
# 1    VI       A  AMIT NISHAD    Male  22841530406                 NaN
# 2    VI       A  ANKIT KUMAR    Male  22722776277                 NaN
# 3    VI       A         ASIF    Male  22731496766                 NaN
# 4    VI       A     HIMANSHU    Male  21792158649         310648154.0
#
#    Father_Name     Mother_Name Social_Category Minority_Group BPL_beneficiary  \
# 0    UNUS KHAN     MEENA BEGAM           4-OBC         Muslim              No
# 1   ANIL KUMAR    KAMAL KETAKI           4-OBC            NaN              No
# 2      CHHUTTU      PAN KUMARI            2-SC            NaN              No
# 3  MUSLIM KHAN  RUKSHANA BEGAM           4-OBC            NaN              No
# 4    HARI BABU           PINKI            2-SC            NaN              No
#
# ...

# %%
sns.barplot(y="sepal_length",x="species",data=iris,palette="rocket")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(y="sepal_length",x="species",data=iris,palette="rocket")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(y="sepal_length",x="species",data=iris,palette="vlag")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(y="sepal_length",x="species",data=iris,palette="Blues_d")
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# ## color without using  palette and using color attribut

# %%
print(sns.barplot(y="sepal_length",x="species",data=iris,color="orange"))
print(sns.barplot(y="sepal_length",x="species",data=iris,color="red"))
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ### color using a list method

# %%
iris.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %% [markdown]
# ### creating a scatter plot seaborn

# %%
sns.scatterplot(x="sepal_length",y="petal_length",data=iris,hue="species")
plt.show()

# %%
sns.scatterplot(x="sepal_length",y="petal_length",data=iris,hue="petal_length")
plt.show()

# %% [markdown]
# ### creating a combination of two graph hist and frequency is called dhist

# %%
sns.distplot(iris["petal_length"],color="orange")
plt.show()
# Out:
# C:\Users\IPCC 8188985998\AppData\Local\Temp\ipykernel_1508\361046438.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris["petal_length"],color="orange")

# %% [markdown]
# ### remove the histograme graph

# %%
sns.distplot(iris["sepal_length"],color="orange",hist=False)
# Out:
# C:\Users\IPCC 8188985998\AppData\Local\Temp\ipykernel_1508\617713091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris["sepal_length"],color="orange",hist=False)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# ### remove the frequency graph

# %%
sns.distplot(iris["petal_width"],color="orange",kde=False)
# Out:
# C:\Users\IPCC 8188985998\AppData\Local\Temp\ipykernel_1508\3894937777.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris["petal_width"],color="orange",kde=False)
# <Axes: xlabel='petal_width'>

# %% [markdown]
# ## creating a  joint plot with seaborn
# ### joint plot is a combination of scatter and histogram

# %%
sns.jointplot(x="petal_length",y="sepal_length",data=iris,color="orange")

# %% [markdown]
# ## adding a regration line between the linegraph histogram and scatter plot

# %%
sns.jointplot(x="petal_length",y="sepal_length",data=iris,color="orange",kind="reg")

# %% [markdown]
# ### create a box plot

# %%
sns.boxplot(x="species",y="petal_length",data=iris)
plt.show()

# %% [markdown]
# ## use palettle

# %%
sns.boxplot(x="species",y="petal_length",data=iris,palette="rocket")
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# ## fix the boundry of box plot by using linewidrth

# %%
sns.boxplot(x="species",y="petal_length",data=iris,palette="rocket",linewidth=9)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
## order change of species using order
sns.boxplot(x="species",y="petal_length",data=iris,palette="rocket",linewidth=9,order=["virginica","setosa","versicolor species"])
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
## use of hue
sns.boxplot(x="species",y="petal_length",data=iris,palette="rocket",linewidth=2,hue="species")
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x="species",y="petal_length",data=iris,palette="rocket",linewidth=9)

# %% [markdown]
# ##  create a pair plot
# ### pairplot is one to one relecational graph

# %%
sns.pairplot(iris,hue="species")
plt.show()
# Out:
# C:\Users\IPCC 8188985998\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
